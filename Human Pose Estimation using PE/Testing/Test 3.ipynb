# %%
import pandas as pd
import numpy as np
import glob as gb

# %%
from google.colab import drive
drive.mount('/content/Google_Drive')
# Out:
# Mounted at /content/Google_Drive

# %%
path=gb.glob('/content/Google_Drive/MyDrive/College /Human Pose Estimation Using Open CV/Images/Coordinates/*.csv')

# %%
cd=[]
i=0
for file in path:
      take=pd.read_csv(file);
      #print(take['Coordinates']) 
      var=take['Coordinates']
      cd.extend(var)     
      break;
arr=np.array(cd)
print(arr)
